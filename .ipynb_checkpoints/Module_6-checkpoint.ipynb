# %% [markdown]
# # Module 6: Purple Data Analysis
#
# Greg Lee
# <br>u0890227
# <br>04.09.20

# %% [markdown]
# This notebook represents an exploration into time series data collected from the purpleair website. These analysis aim to examine a subset of experimental data collected for one day (4/08/20) at hourly measurements. This analysis acts an intial foray into the data which will be used for the final project.
#
# **PurpleAir**
# <br>PurpleAir sensors measure airborne particulate matter (PM). Particulate matter describes solid particles suspended in air; this includes dust, smoke, and other organic and inorganic particles. PurpleAir sensors use laser particle counters to count the number of particles by particle sizes 0.3, 0.5, 1, 2.5, 5, and 10 μm, and use the count data to calculate mass concentrations of PM1.0, PM2.5, and PM10.
#
# Some information regarding legacy data:
#
# | Abbreviation | Explanation |
# |------|------|
# |ID: | PurpleAir Sensor|
# |Parent ID: | The PurpleAir sensor ID of the "parent" entry in the case of Channel B|
# |THINGSPEAK_PRIMARY_ID |The Thingspeak channel ID for primary data of this sensor|
# |THINGSPEAK_PRIMARY_ID_READ_KEY | The Thingspeak read key for primary data of this sensor |
# |Label| The "name" that appears on the map for this sensor|
# |Lat| Latitude position info|
# |Lon|Longitude position info|
# |PM2_5Value|Current PM2.5 value|
# |State|Unused variable|
# |Type|Sensor type (PMS5003, PMS1003, BME280 etc)|
# |Hidden|Hide from public view on map: true/false|
# |Flag|Data flagged for unusually high readings|
# |DEVICE_BRIGHTNESS|LED brightness (if hardware is present)|
# |isOwner|Currently logged in user is the sensor owner|
# |A_H|true if the sensor output has been downgraded or marked for attention due to suspected hardware|
# |temp_f|Current temperature in F|
# |humidity|Current humidity in %|
# |pressure|Current pressure in Millibars|
# |AGE|Sensor data age (when data was last received) in minutes|
# |THINGSPEAK_SECONDARY_ID|The Thingspeak channel ID for secondary data of this sensor|
# |THINGSPEAK_SECONDARY_ID_READ_KEY|The Thingspeak read key for secondary data of this sensor|
# |LastSeen|Last seen data time stamp in UTC|
# |Version|Current version of sensor firmware|
# |LastUpdateCheck|Last update checked at time stamp in UTC|
# |Uptime|Sensor uptime in seconds|
# |RSSI|Sensor's WiFi signal strength in dBm|
# |Stats|Statistics for PM2.5|

# %% [markdown]
# ### Question
#
# How do the PM levels change throughout Utah over a 24 hour period?

# %% [markdown]
# # Libraries:

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import os
from scipy.spatial.distance import cdist
import numpy as np
import seaborn as sb

#Date
from datetime import datetime
import pytz

#Geography
import geopandas as gpd
import fiona
from shapely.geometry import Point
import descartes
import contextily as ctx #Basemaps 

#Modeling
import statsmodels.formula.api as smf
import statsmodels.api as sm

# %% [markdown]
# # Import the Data
#
# All data presented here was collected utilizing an airflow system for JSON information collection at hourly rates. More detail will be given for the final project on this process. Here we grab the data for a 24 hr. period starting on April 8th at 12:00AM MST.

# %%
directory = '/home/boogie2/external/tiny_tower_2/purpleair_data/'
data_direct = []

#Create a directory of the data
for filename in os.listdir(directory):
    
    #append the path to the list
    data_direct.append(os.path.join(directory, filename))
    
    #sort the data
    data_direct = sorted(data_direct)

# %%
#Grab the legacy data for April 8th
leg_dir = []

for entries in data_direct:
        
    #Collect the legacy data    
    if "legacy_04_08" in str(entries):
        leg_dir.append(entries)

print("The legacy directory has {0} entries".format(len(leg_dir)))
# Out:
# The legacy directory has 24 entries

# %%
#These numbers seem reasonable for 24 hrs. Let's append to a pandas dataframe

#This function will help put the data into a larger dataframe
def concater(temp_dir):
    data = []

    for dirs in temp_dir:
        temp_df = pd.read_pickle(dirs)
        
        if 'legacy' in dirs:
            temp_df['Time']= dirs.split('legacy_')[1].split('.pkl')[0]
            
        data.append(temp_df)

    return(pd.concat(data))

legacy_df = concater(leg_dir)
legacy_df.head(2)
# Out:
#   mapVersion baseVersion mapVersionString     ID                 Label  \
# 0        0.4           7                   14633     Hazelwood canary
# 1        0.4           7                   14634   Hazelwood canary  B
#
#   DEVICE_LOCATIONTYPE THINGSPEAK_PRIMARY_ID THINGSPEAK_PRIMARY_ID_READ_KEY  \
# 0             outside                559921               CU4BQZZ38WO5UJ4C
# 1                 NaN                559923               DULWDNCI9M6PCIPC
#
#   THINGSPEAK_SECONDARY_ID THINGSPEAK_SECONDARY_ID_READ_KEY  ...  temp_f  \
# 0                  559922                 D0YNZ1LM59LL49VQ  ...      63
# 1                  559924                 EY2CNMYRUZHDW1AL  ...     NaN
#
#    pressure AGE                                              Stats ParentID  \
# 0   1008.75   1  {"v":0.58,"v1":0.58,"v2":0.61,"v3":0.72,"v4":1...      NaN
# 1       NaN   1  {"v":0.0,"v1":0.05,"v2":0.08,"v3":0.13,"v4":0....  14633.0
#
#   Flag  A_H Voc Ozone1         Time
# ...

# %%
#PurpleAir Data represents sensors from around the country. Here we select Utah by a bounding box. 
#NOTE: a little bit of Wyoming is included!

ut_leg_df = legacy_df[(legacy_df['Lat']>=37.043937)&
          (legacy_df['Lat']<=41.98959) &
         (legacy_df['Lon']<= -108.936278) &
         (legacy_df['Lon']>= -113.989989)]

# %%
#We need to set the date and time as an object in MST for better ease of analysis
ut_leg_df = ut_leg_df.reset_index(drop=True)
ut_leg_df['Time'] = ut_leg_df['Time'].apply(lambda x: 
                                       datetime.strptime(str('20_'+x),
                                                         "%y_%m_%d_%H_%M"))

#Set the timezone
tz = pytz.timezone("America/Denver")
ut_leg_df['Time'] = ut_leg_df['Time'].apply(lambda x: tz.localize(x))

# %% [markdown]
# # Data Description:

# %%
print("Purpleair Utah Legacy Data Shape {0} x {1}".format(ut_leg_df.shape[0],
                                        ut_leg_df.shape[1]))
# Out:
# Purpleair Utah Legacy Data Shape 24650 x 28

# %%
print("Total number of sensors in the data: {0}".format(ut_leg_df['ID'].drop_duplicates().shape[0]))
# Out:
# Total number of sensors in the data: 1030

# %%
print('Minimum Date: {0}'.format(ut_leg_df['Time'].min()))
print('Maximum Date: {0}'.format(ut_leg_df['Time'].max()))
# Out:
# Minimum Date: 2020-04-08 00:00:00-06:00
# Maximum Date: 2020-04-08 23:00:00-06:00

# %%
#What do the nan's in the data look like? 
ut_leg_df.isna().sum().sort_values()
# Out:
# mapVersion                              0
# AGE                                     0
# isOwner                                 0
# Hidden                                  0
# Lon                                     0
# Lat                                     0
# THINGSPEAK_SECONDARY_ID_READ_KEY        0
# THINGSPEAK_SECONDARY_ID                 0
# LastSeen                                0
# THINGSPEAK_PRIMARY_ID                   0
# baseVersion                             0
# THINGSPEAK_PRIMARY_ID_READ_KEY          0
# mapVersionString                        0
# ID                                      0
# Time                                    0
# Label                                   0
# PM2_5Value                           1401
# Stats                                1401
# Type                                12013
# humidity                            12517
# pressure                            12517
# temp_f                              12517
# ...

# %%
ut_leg_df.dtypes
# Out:
# mapVersion                                                  object
# baseVersion                                                 object
# mapVersionString                                            object
# ID                                                           int64
# Label                                                       object
# DEVICE_LOCATIONTYPE                                         object
# THINGSPEAK_PRIMARY_ID                                       object
# THINGSPEAK_PRIMARY_ID_READ_KEY                              object
# THINGSPEAK_SECONDARY_ID                                     object
# THINGSPEAK_SECONDARY_ID_READ_KEY                            object
# Lat                                                        float64
# Lon                                                        float64
# PM2_5Value                                                  object
# LastSeen                                                     int64
# ...

# %%
#Recast data types
ut_leg_df = ut_leg_df.astype({'PM2_5Value': 'float64',
                 'humidity':'float64',
                 'temp_f': 'float64',
                 'pressure': 'float64',
                 'Ozone1': 'float64'})

# %%
ut_leg_df.describe()
# Out:
#                  ID           Lat           Lon    PM2_5Value      LastSeen  \
# count  24650.000000  24650.000000  24650.000000  23249.000000  2.465000e+04
# mean   19388.583489     40.606641   -111.844952     23.544952  1.586313e+09
# std    14195.169807      0.608761      0.364856    320.835997  2.969742e+05
# min       20.000000     37.052847   -113.986114      0.000000  1.583975e+09
# 25%     6348.000000     40.475832   -111.922076      0.560000  1.586344e+09
# 50%    16012.000000     40.672575   -111.860698      1.450000  1.586365e+09
# 75%    30942.000000     40.774129   -111.760208      2.810000  1.586387e+09
# max    49256.000000     41.764022   -109.496450   6147.830000  1.586408e+09
#
#        isOwner      humidity        temp_f      pressure           AGE  \
# count  24650.0  12133.000000  12133.000000  12133.000000  24650.000000
# mean       0.0     29.172999     66.358444    850.285616    900.418661
# ...

# %%
#Visualization of sensor location
sensor_set = ut_leg_df.drop_duplicates(subset='ID', keep="first")

sensor_gdf = gpd.GeoDataFrame(sensor_set, geometry=gpd.points_from_xy(sensor_set.Lon, 
                                                                      sensor_set.Lat))
sensor_gdf.crs = {'init' :'epsg:4326'}
sensor_gdf = sensor_gdf.to_crs({'init': 'epsg:3857'})

#Plotting
fig, ax = plt.subplots(1,1,figsize = (10,10))
sensor_gdf.plot(ax = ax,color = 'k',markersize = 5,marker='o')
plt.title("Reporting PurpleAir Sensors: 04.08.20")
plt.axis('off')
ctx.add_basemap(ax)
# Out:
# /home/boogie2/anaconda3/envs/purp_air/lib/python3.7/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %% [markdown]
# **Conclusions**
# 1. PM2.5 data is missing for a small portion of the data. For these sensors, let's try and do some interpolation.
# 2. Humidity, pressure, temperature all seem to be useful pieces of information. Although almost 50% of the data is missing these values... Let's try some interpolation for these values although this will definetly incorperate some error into the model. Note, since most of these sensors are typically located within urban settings, this may skew observations towards those conditions.
# 3. While it would be interesting to look into Ozone and Voc's, there are too many missing values to make interpolation relevant. These features will be dropped.
#
#
# 4. The average temperature in Utah on April 8th was 66 degrees farenheight
# 5. TThe average age of sensor is 900 days ~ 3 years
# 6. The average humidity was 29.172 %H20
# 7. The average PM25 value was 23.544 in EPA PM2.5 AQI values

# %% [markdown]
# # Dealing with Null Values

# %%
#Let's first grab the data of interest
ut_df = ut_leg_df[['ID','AGE','Lon','Lat','LastSeen','Time','PM2_5Value','temp_f','pressure','humidity']]

# %%
#Fill in the PM25 data with the closest (from a spatial point of view)
def closest_point(point, points):
    """ Find closest point from a list of points. """
    return points[cdist([point], points).argmin()]

def match_value(df, col1, x, col2):
    """ Match value x from col1 row to value in col2. """
    return df[df[col1] == x][col2].values[0]

filled_pm25 = ut_df[ut_df['PM2_5Value'].notna()]
missing_pm25 = ut_df[ut_df['PM2_5Value'].isna()]

#Create point entry
filled_pm25['point'] = [(x, y) for x,y in zip(filled_pm25['Lat'], filled_pm25['Lon'])]
missing_pm25['point'] = [(x, y) for x,y in zip(missing_pm25['Lat'], missing_pm25['Lon'])]

#Finds the closest point for all data
closest_points = [closest_point(x, list(filled_pm25['point'])) for x in missing_pm25['point']]
# Out:
# /home/boogie2/anaconda3/envs/purp_air/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/boogie2/anaconda3/envs/purp_air/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %%
for index, point in enumerate(closest_points):
    similiar = filled_pm25[filled_pm25['point'] == point]
    most_sim = similiar[similiar['Time'] == missing_pm25['Time'].iloc[index]]
    
    if most_sim.temp_f.isna().iloc[0] == True:
        print("For Index: {0}, Missing temperature and other values".format(index))
        
    missing_pm25['PM2_5Value'].iloc[index] = most_sim['PM2_5Value'].iloc[0]
# Out:
# /home/boogie2/anaconda3/envs/purp_air/lib/python3.7/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# /home/boogie2/anaconda3/envs/purp_air/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# For Index: 14, Missing temperature and other values
# For Index: 72, Missing temperature and other values
# For Index: 130, Missing temperature and other values
# For Index: 188, Missing temperature and other values
# For Index: 246, Missing temperature and other values
# ...

# %%
#PM25 is filled!
ut_df_pm25_fill = filled_pm25.append(missing_pm25)
ut_df_pm25_fill.isna().sum()
# Out:
# ID                0
# AGE               0
# Lon               0
# Lat               0
# LastSeen          0
# Time              0
# PM2_5Value        0
# temp_f        12517
# pressure      12517
# humidity      12517
# point             0
# dtype: int64

# %%
ut_df_pm25_fill.columns
# Out:
# Index(['ID', 'AGE', 'Lon', 'Lat', 'LastSeen', 'Time', 'PM2_5Value', 'temp_f',
#        'pressure', 'humidity', 'point'],
#       dtype='object')

# %% [markdown]
# ## Let's repeat a similiar process for temperature, pressure and humidity

# %%
#we will make the assumption that if missing temperature, the values will all be missing
filled = ut_df_pm25_fill[ut_df_pm25_fill['temp_f'].notna()]
missing = ut_df_pm25_fill[ut_df_pm25_fill['temp_f'].isna()]

#Finds the closest point for all data
closest_points = [closest_point(x, list(filled['point'])) for x in missing['point']]

# %%
for index, point in enumerate(closest_points):
    similiar = filled[filled['point'] == point]
    most_sim = similiar[similiar['Time'] == missing['Time'].iloc[index]]   
    missing['temp_f'].iloc[index] = most_sim['temp_f'].iloc[0]
    missing['pressure'].iloc[index] = most_sim['pressure'].iloc[0]
    missing['humidity'].iloc[index] = most_sim['humidity'].iloc[0]
# Out:
# /home/boogie2/anaconda3/envs/purp_air/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/boogie2/anaconda3/envs/purp_air/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /home/boogie2/anaconda3/envs/purp_air/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
ut_df_filled = filled.append(missing)
ut_df_filled.isna().sum()
# Out:
# ID            0
# AGE           0
# Lon           0
# Lat           0
# LastSeen      0
# Time          0
# PM2_5Value    0
# temp_f        0
# pressure      0
# humidity      0
# point         0
# dtype: int64

# %% [markdown]
# Further analysis reveals that several of the sensors have extreme values and are most likely miscalibrated. Let's remove those. I am creating a cutoff at 500 as this value is the maximum purple air PM2.5 measurement according to their website.

# %%
ut_df_filled = ut_df_filled[ut_df_filled['PM2_5Value']<500].reset_index(drop=True)

# %% [markdown]
# # Visualization:
#
# In order to visualize this data: I think it best to perform a county level mean aggregation. This will give 29 area of Utah for analysis which seems more reasonable

# %%
#Let's visualize a single sensor first: 
samp_pm25 = ut_df_filled[ut_df_filled['ID'] == 10808][['Lon','Lat','Time','PM2_5Value']]

samp_pm25_gdf = gpd.GeoDataFrame(samp_pm25, geometry=gpd.points_from_xy(samp_pm25.Lon,samp_pm25.Lat))
samp_pm25_gdf.crs = {'init' :'epsg:4326'}
samp_pm25_gdf = samp_pm25_gdf.to_crs({'init': 'epsg:3857'})

# Set up the plotting environment
f,ax = plt.subplots(1,2,figsize=(16,8))

# Put the "date" column as an index, access the remaining "passengers" column, and plot on the ax defined above
samp_pm25.set_index('Time')['PM2_5Value'].plot(c='k',lw=3,ax=ax[0])
ax[0].set_title('24 Hour PM2.5 Measurments Example')
ax[0].set_xlabel('Time (hrs)')
ax[0].set_ylabel('PM2.5')

#plot the location
samp_pm25_gdf.plot(ax = ax[1],color = 'k',markersize = 20,marker='o')
ax[1].set_title('Sensor Location')
ax[1].set_xlim(-1.249e7, -1.242e7)
ax[1].set_ylim(4910000, 4960000)
ctx.add_basemap(ax[1])
# Out:
# /home/boogie2/anaconda3/envs/purp_air/lib/python3.7/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %% [markdown]
# So this point stems from near point of the mountain! Interesting to see the spike happen in the morning (6-9AM)

# %%
#Merge by County:
counties =fiona.open('utah_counties.gdb')
counties.driver # OpenFileGDB
counties.schema # {'geometry': '3D MultiLineString', 'properties': OrderedDict([(u'FCSubtype', 'int'), ...
counties.crs # {'init': u'epsg:4326'}

# Build the GeoDataFrame from Fiona Collection
counties_gdf = gpd.GeoDataFrame.from_features([feature for feature in counties], crs=counties.crs)
# Get the order of the fields in the Fiona Collection; add geometry to the end
columns = list(counties.meta["schema"]["properties"]) + ["geometry"]
# Re-order columns in the correct order
counties_gdf = counties_gdf[columns]
# Out:
# /home/boogie2/anaconda3/envs/purp_air/lib/python3.7/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
ut_fill_gdf = gpd.GeoDataFrame(ut_df_filled, geometry=gpd.points_from_xy(ut_df_filled.Lon,ut_df_filled.Lat))
ut_fill_gdf.crs = {'init' :'epsg:4326'}
ut_fill_gdf = ut_fill_gdf.to_crs({'init': 'epsg:3857'})

# %%
#Let's get only the country data using a spatial join
count_spa_joi = gpd.sjoin(ut_fill_gdf, counties_gdf, op= 'within')
county_hr_25 = count_spa_joi.groupby(['NAME','Time'])['PM2_5Value'].mean()
count_hr_25 = pd.DataFrame(county_hr_25).reset_index()

# %%
count_hr_25_gdf = count_hr_25.merge(counties_gdf, on='NAME', how='outer')

#Which counties have zero measurments?
count_hr_25_gdf['NAME'][count_hr_25_gdf['Time'].isna()]
# Out:
# 432     MILLARD
# 433        RICH
# 434      CARBON
# 435     DAGGETT
# 436      BEAVER
# 437      SEVIER
# 438    GARFIELD
# 439       PIUTE
# 440        IRON
# 441       EMERY
# 442    SAN JUAN
# Name: NAME, dtype: object

# %%
#What are the counts per sensor before joining
totals = count_spa_joi.groupby(['NAME','Time'])['PM2_5Value'].count()
totals = pd.DataFrame(totals).reset_index()
pm_counts = totals.drop_duplicates('NAME')

#There are differing counts for Salt Lake throughout the day so let's just average these values to create one value
pm_counts['PM2_5Value'][pm_counts['NAME']=='SALT LAKE'].mean()

pm_counts_sel = pm_counts[pm_counts['NAME']!='SALT LAKE']
pm_counts_sel.reset_index(drop=True)
# Out:
#           NAME                      Time  PM2_5Value
# 0    BOX ELDER 2020-04-08 00:00:00-06:00          28
# 1        CACHE 2020-04-08 00:00:00-06:00          16
# 2        DAVIS 2020-04-08 00:00:00-06:00         100
# 3     DUCHESNE 2020-04-08 00:00:00-06:00           4
# 4        GRAND 2020-04-08 00:00:00-06:00           6
# 5         JUAB 2020-04-08 00:00:00-06:00           2
# 6         KANE 2020-04-08 00:00:00-06:00           2
# 7       MORGAN 2020-04-08 00:00:00-06:00           6
# 8      SANPETE 2020-04-08 00:00:00-06:00           2
# 9       SUMMIT 2020-04-08 00:00:00-06:00          56
# 10      TOOELE 2020-04-08 00:00:00-06:00          25
# 11      UINTAH 2020-04-08 00:00:00-06:00           2
# 12        UTAH 2020-04-08 00:00:00-06:00         191
# 13     WASATCH 2020-04-08 00:00:00-06:00          18
# 14  WASHINGTON 2020-04-08 00:00:00-06:00          16
# 15       WAYNE 2020-04-08 00:00:00-06:00           2
# 16       WEBER 2020-04-08 00:00:00-06:00          57

# %%
pm_counts_sel = pm_counts_sel.append({'NAME':'SALT LAKE',
                      'Time':pm_counts_sel['Time'].iloc[1],
                      'PM2_5Value':pm_counts['PM2_5Value'][pm_counts['NAME']=='SALT LAKE'].mean()}, ignore_index=True)
#Order by Counts
pm_counts_sel = pm_counts_sel.sort_values(by='PM2_5Value')

#Plot
f,ax = plt.subplots(1,1,figsize=(8,8))
ax.bar(pm_counts_sel['NAME'],pm_counts_sel['PM2_5Value'])
ax.set_xticklabels(pm_counts_sel['NAME'], rotation = 45, ha="right")
ax.set_xlabel('County')
ax.set_ylabel('Observations per County')
ax.set_title('PurpleAir Monitors in Utah Counties')
# Out:
# Text(0.5, 1.0, 'PurpleAir Monitors in Utah Counties')

# %%
#Plot the counties....

county_pm25 = sb.catplot(x='Time',
                         y='PM2_5Value',
                         hue='NAME',
                         data=count_hr_25_gdf,
                         kind='point',
                         aspect=2,
                         palette = 'Paired')
county_pm25.set_xticklabels(rotation = 45, ha="right")
county_pm25.set(title = 'County Average PM2.5 Levels on April 8th 2020')

# %% [markdown]
# **Conclusion**
# 1. The air quality varies considerably with no distinct spikes in any county throughout the day.
# 2. These analysis are highly sensitive to outliers

# %%
#Let's visualize the daily average for each county
daily_avg = count_hr_25_gdf.groupby(['NAME'])['PM2_5Value'].mean()
daily_avg = pd.DataFrame(daily_avg).reset_index()
daily_avg = daily_avg.replace(np.nan,0)
daily_avg = daily_avg.rename(columns = {'PM2_5Value':'Avg_PM25'})
daily_avg_gdf = daily_avg.merge(counties_gdf, on='NAME', how='outer')

daily_avg_gdf = daily_avg_gdf[daily_avg_gdf['Avg_PM25']<500]

# %%
# Set up the plotting environment
f,ax = plt.subplots(1,1,figsize=(20,20))
daily_avg_gdf = gpd.GeoDataFrame(daily_avg_gdf)
daily_avg_gdf.plot(ax = ax,
                  column='Avg_PM25',
                  cmap = 'Oranges',
                  alpha =0.6,
                  legend =True)
plt.title("County-Level Aggregation on PM25 Data")

ctx.add_basemap(ax)

# %% [markdown]
# This map makes more sense than previous iterations. The air quality is highest in counties with highly dense urban populations. Please note, that none of these averages reach "dangerous" air quality levels and are all extremely low in the relative scheme for Utah winter.

# %%
#Let's take a look around the UofU and see if there are any areas which experience 
#high levels of pm2.5
all_sensors = count_spa_joi.merge(counties_gdf, on='NAME', how='outer')
slc_sens  = all_sensors[all_sensors['NAME']=='SALT LAKE'].reset_index(drop=True)

#How many total measurments?
slc_sens.shape
# Out:
# (11756, 39)

# %%
slc_sens = slc_sens[['Lon','Lat','Time','PM2_5Value','temp_f','pressure','humidity',
                          'NAME','ID']]
pm = pd.DataFrame(slc_sens.groupby('ID')['PM2_5Value'].mean())

#group two grab the lat long back

slc_sense = pm.merge(slc_sens.drop_duplicates('ID'), on='ID', how='outer')

# %%
slc_sense_gdf
# Out:
#           ID  PM2_5Value_x         Lon        Lat                      Time  \
# 0       20.0      0.901667 -111.836119  40.603078 2020-04-08 00:00:00-06:00
# 1       47.0      1.040000 -111.882598  40.476203 2020-04-08 00:00:00-06:00
# 2       72.0     23.545417 -111.947073  40.770191 2020-04-08 00:00:00-06:00
# 3       74.0      0.000000 -111.936248  40.738261 2020-04-08 00:00:00-06:00
# 4       77.0      4.797500 -111.825285  40.750817 2020-04-08 00:00:00-06:00
# ..       ...           ...         ...        ...                       ...
# 488  49062.0      1.941250 -111.840208  40.748309 2020-04-08 00:00:00-06:00
# 489  49155.0      2.705833 -111.882289  40.735126 2020-04-08 00:00:00-06:00
# 490  49156.0      2.774583 -111.882289  40.735126 2020-04-08 00:00:00-06:00
# 491  49255.0      3.987083 -111.857021  40.549956 2020-04-08 00:00:00-06:00
# 492  49256.0      4.035833 -111.857021  40.549956 2020-04-08 00:00:00-06:00
#
# ...

# %%
#Plot the average pm25 around the U of U for April 8th
slc_sense_gdf = gpd.GeoDataFrame(slc_sense, geometry=gpd.points_from_xy(slc_sense.Lon,slc_sense.Lat))
slc_sense_gdf.crs = {'init' :'epsg:4326'}
slc_sense_gdf = slc_sense_gdf.to_crs({'init': 'epsg:3857'})

# Set up the plotting environment
f,ax = plt.subplots(1,1,figsize=(16,16))


#plot the location
slc_sense_gdf.plot(ax = ax,
                   column ='PM2_5Value_x',
                  cmap = 'Blues_r',
                  legend ='True')
ax.set_xlim(-1.2455e7, -1.2448e7)
ax.set_ylim(4970000, 4980000)
ax.set_title('PM2.5 Averages on April 8th Near the U of U ')
ctx.add_basemap(ax)
# Out:
# /home/boogie2/anaconda3/envs/purp_air/lib/python3.7/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %% [markdown]
# ### Decomposition:
#
# For ease of visualization, I plan to only work with the salt lake county data as the measurments for this area are least likely to be skewed by a small number of sensors. Furthermore, it would be best to perform this analysis over a greater amount of time, to truly distill daily trends.

# %%
#Let's get only the country data using a spatial join for all features
county_hour_all = count_spa_joi.groupby(['NAME','Time'])['PM2_5Value','temp_f','pressure',
                                                     'humidity'].mean()
county_hour_all = pd.DataFrame(county_hour_all).reset_index()
county_hour_all = county_hour_all.merge(counties_gdf, on='NAME', how='outer')

#Remove timezones, not helping with modeling
county_hour_all['Time'] = county_hour_all['Time'].apply(lambda x: x.replace(tzinfo=None))

#Reset an hours column
county_hour_all['hours'] = (county_hour_all['Time'] - pd.Timestamp('2020-04-08 00:00:00'))/pd.Timedelta(1,'H')
# Out:
# /home/boogie2/anaconda3/envs/purp_air/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %% [markdown]
# #### Salt Lake County

# %%
salt_lake = county_hour_all[county_hour_all['NAME']=='SALT LAKE']
utah = county_hour_all[county_hour_all['NAME']=='UTAH']

#Let's decompose the salt lake data
decomposition = sm.tsa.seasonal_decompose(
    salt_lake.set_index('Time')['PM2_5Value'],period=3)

plt.rcParams["figure.figsize"] = (8,8)
f = decomposition.plot()

# %%
#Create a salt lake simple regression model
m0 = smf.ols('PM2_5Value ~ hours',data=salt_lake).fit()
m0.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             PM2_5Value   R-squared:                       0.486
# Model:                            OLS   Adj. R-squared:                  0.463
# Method:                 Least Squares   F-statistic:                     20.81
# Date:                Sat, 11 Apr 2020   Prob (F-statistic):           0.000153
# Time:                        15:38:04   Log-Likelihood:                -18.306
# No. Observations:                  24   AIC:                             40.61
# Df Residuals:                      22   BIC:                             42.97
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.6304      0.214     12.263      0.000       2.186       3.075
# ...

# %% [markdown]
# **Conclusion**
# <br>
# This is a pretty poor model, as it only explains ~ 48.6% of the variance within the model.
#
# Let's try adding in a few more features to see if that helps at all!

# %%
#Salt Lake County
m0 = smf.ols('PM2_5Value ~ hours + temp_f + pressure + humidity',data=salt_lake).fit()
m0.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             PM2_5Value   R-squared:                       0.631
# Model:                            OLS   Adj. R-squared:                  0.554
# Method:                 Least Squares   F-statistic:                     8.132
# Date:                Sat, 11 Apr 2020   Prob (F-statistic):           0.000535
# Time:                        15:38:06   Log-Likelihood:                -14.323
# No. Observations:                  24   AIC:                             38.65
# Df Residuals:                      19   BIC:                             44.54
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -109.1774     98.830     -1.105      0.283    -316.032      97.677
# ...

# %% [markdown]
# #### Utah County

# %%
#Let's decompose the Utah County Data
decomposition = sm.tsa.seasonal_decompose(
    utah.set_index('Time')['PM2_5Value'],period=3)

plt.rcParams["figure.figsize"] = (8,8)
f = decomposition.plot()

# %%
#What about in Utah County? 
m0 = smf.ols('PM2_5Value ~ hours + temp_f + pressure + humidity',data=utah).fit()
m0.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             PM2_5Value   R-squared:                       0.703
# Model:                            OLS   Adj. R-squared:                  0.641
# Method:                 Least Squares   F-statistic:                     11.25
# Date:                Sat, 11 Apr 2020   Prob (F-statistic):           7.51e-05
# Time:                        15:38:11   Log-Likelihood:                -12.570
# No. Observations:                  24   AIC:                             35.14
# Df Residuals:                      19   BIC:                             41.03
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    183.0897    145.288      1.260      0.223    -121.001     487.180
# ...

# %% [markdown]
# **Conclusion**
# <br>Adding some information about the temperature pressure and humidity greatly improves prediction allowing the model to explain 63% of variance for the Salt Lake Region. Interestingly hours is the best feature at predicting the PM value for the Utah Region but not for the Salt Lake County Data. This may be a signal that certain calibrations were off, or that humidity can affect PM levels. More analysis would be necessary to support these conclusions.

# %% [markdown]
# ### Auto and Partial Autocorrelation

# %%
#Utah County
f,axs = plt.subplots(2,1,figsize=(8,8))

fig1 = sm.graphics.tsa.plot_acf(utah['PM2_5Value'],zero=False,lags=23,ax=axs[0],alpha=.05)
fig2 = sm.graphics.tsa.plot_pacf(utah['PM2_5Value'],zero=False,lags=23,ax=axs[1],alpha=.05)

for ax in axs:
    ax.axvline(12,c='r',ls='--',lw=1)
    ax.axvline(24,c='r',ls='--',lw=1)
# Out:
# /home/boogie2/anaconda3/envs/purp_air/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1406: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %%
#Salt Lake County
f,axs = plt.subplots(2,1,figsize=(8,8))

fig1 = sm.graphics.tsa.plot_acf(salt_lake['PM2_5Value'],zero=False,lags=23,ax=axs[0],alpha=.05)
fig2 = sm.graphics.tsa.plot_pacf(salt_lake['PM2_5Value'],zero=False,lags=23,ax=axs[1],alpha=.05)

for ax in axs:
    ax.axvline(12,c='r',ls='--',lw=1)
    ax.axvline(24,c='r',ls='--',lw=1)
# Out:
# /home/boogie2/anaconda3/envs/purp_air/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1406: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %% [markdown]
# ### Prophet Modeling

# %%
from fbprophet import Prophet

# %%
salt_lake.columns
# Out:
# Index(['NAME', 'Time', 'PM2_5Value', 'temp_f', 'pressure', 'humidity',
#        'COUNTYNBR', 'ENTITYNBR', 'ENTITYYR', 'FIPS', 'STATEPLANE',
#        'POP_LASTCENSUS', 'POP_CURRESTIMATE', 'GlobalID', 'FIPS_STR', 'COLOR4',
#        'SHAPE_Length', 'SHAPE_Area', 'geometry', 'hours'],
#       dtype='object')

# %%
#Rename for prophet analysis:
slc_model = Prophet()
slc_test = salt_lake[['Time','PM2_5Value']].rename(columns = {'Time':'ds',
                                                   'PM2_5Value':'y'})
slc_model.fit(slc_test)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 18.

# %%
#Make some predictions about PM25 in SLC
slc_future = slc_model.make_future_dataframe(periods=48,freq='H')

slc_forcast = slc_model.predict(slc_future)

# Lots of columns returned, just look at the choice ones
slc_forcast[['ds','yhat','yhat_lower','yhat_upper']].head()
# Out:
#                    ds      yhat  yhat_lower  yhat_upper
# 0 2020-04-08 00:00:00  2.630343    1.979534    3.274353
# 1 2020-04-08 01:00:00  2.703253    2.037215    3.372229
# 2 2020-04-08 02:00:00  2.776163    2.112895    3.423621
# 3 2020-04-08 03:00:00  2.849072    2.208019    3.546912
# 4 2020-04-08 04:00:00  2.921982    2.340452    3.605085

# %%
f,ax = plt.subplots(1,1,figsize=(10,5))
_ = slc_model.plot(slc_forcast,ax=ax)

# Always label your axes
ax.set_xlabel('Hourly')
ax.set_ylabel('PM2.5')
ax.set_title('Observation and Forecast for PM2.5 in Utah')
# Out:
# Text(0.5, 1.0, 'Observation and Forecast for PM2.5 in Utah')

# %% [markdown]
# **Conclusion**
# <br>This model is a linear regression for the data, since the number of data points. It appears to be not very accurate as PM25 values for SLC should not increase linearly. This is expected though as the data subsample is small.

# %% [markdown]
# # Write-Up

# %% [markdown]
#     The Salt Lake City basin is well known as a growing hub of activity with quick access to great skiing and climbing. Unfortunately, the geographic shape of the region leads to “sinkholes” of pollution, particularly particulate matter (PM) and ozone. In the winter it is common to see inversion set in after long storm cycles. With reduced weather and wind, warm air traps cold air in the Salt Lake basin resulting in cooler temperatures closer to the earth. The byproducts of manufacturing and transportation are also caught in the cold air layer. These trapped particulates are dangerous to human health and careful monitoring is essential to preventing toxic exposure. Particulate matter 2.5 (PM2.5) is robustly associated with many negative disease outcomes including non-fatal heart attacks, asthma and increased cancer risk. Within Utah, the tracking, analysis and forecasting of PM2.5 is critical in protecting public health.
#
#     Currently, my final project focuses on time-series data – the collection of PurpleAir and Airnow data to explore air pollution across the state. In order to perform a robust analysis, this module represents an initial foray into the PurpleAir data for a 24 hour cycle on April 8th. Data was collected from the PurpleAir website, by scraping all measurements at hourly increments utilizing an Airflow workflow. This automated scheduler required the building of a directed acyclic graph to run the scraping. Once created, this task collects both the “legacy” and “experimental” data from PurpleAir, orients them in a data frame and saves the data as a .pkl file. This script cannot backfill or log entries from the past.
#
# 	Several cleaning steps were required to clean and standardize the data. All sensor data was loaded and Utah data was selected by utilizing a Lat/Long bounding box. This resulted in ~25,000 data points for 1030 unique sensors spread across Utah. More sensors may exist but did not send signal on April 8th from 12:00AM to 12:00PM. Examination of the data yielded roughly ~1400 null PM2.5 measurements and ~12,000 null measurements for temperature, humidity and pressure. All other legacy measurements were considered too sparse for accurate filling. Since these data contain both temporal and spatial components, a “nearest-neighbor” method was used for null filling. For each sensor with missing values, the nearest non-null sensor was found by minimizing Euclidean distance. Then, a time-match was performed to fill the null value with the closest sensor both spatially and temporally. Additionally, several sensors were found to push high values often. Thus, any sensor recording over 500, the expected max for PM2.5 was removed.
#
# 	Next, the sensor locations were visualized. As expected, highly metropolitan areas contained the highest number of sensors (Salt Lake, Utah, David and Weber). All sensor data was then aggregated by county location to increase the interpretability. Plotting the PM2.5 data over a 24 hour period showcased consistently low, non-dangerous levels of PM2.5. Perhaps the most prominent spikes in PM2.5 occur in Sanpete around 1:00 and 8:00PM. To visualize the average PM2.5 across each county, a heatmap was created, to showcase counties with increased PM2.5 As expected, these daily averages were higher for the areas where the population density is high. Note, the upregulations were minimal on a relative scale where above 100 is considered hazardous for the average person.
#
# 	Decomposition was attempted for Salt Lake County and Utah County. This analysis was limited as the cycle is short and representative of a single day. County separation was maintained in order to account for geographical differences and minimize noise. For April 8th in Salt Lake PM2.5 generally increased throughout the day while Utah county saw a spike around 12:00PM with a fall shortly after. When modeled with basic linear regression, the fit was poor with only 48.6% and 54.5% of the variance being explained by a simple model. Adding in temperature, humidity and pressure boosted model performance with multi-linear regression resulting in an R2 value of 0.63 and 0.70 for each county respectively.
#
# 	In addition to modeling, auto and partial correlation were calculated on the Salt Lake and Utah county data. These plots showed very few of the cycles being predictive of the previous. Interesting, for both, it seemed that those measurements closest to the 24 hour mark were considered the most predicative. These analysis will become more interesting with an increased amount of data with some cyclical pattern.  Finally, prophet was utilized to make some predictions about the PM2.5 levels in Salt Lake in the following 48 hours. Visualization showed predictions increasing PM2.5 linearly with time. This trend is obviously incorrect as PM2.5 will vary based upon a plethora of factors (or perhaps this truly is the end of the world!). Nonetheless, this speaks on the data “hungry” nature of predictive models to become accurate.
#
# 	These analysis were most limited by data size. The modeling was inaccurate and cleaning ungrounded as an acceptable level of context could not be established from the data. This work acts as a great example of a “cold-start” algorithm, where the initial predictions are poor because the body of data is simplistic and uniform. Of note, the PurpleAir sensors are notorious for their inaccuracies. Several points were found in the data which contained readings above 5000 while the remainder of the nearby (<10km) sensors showcased values <10. This calls into question the accuracy of these sensors and bias of location. In this case, it may be better to overestimate the PM2.5 in order to ensure inaccuracies do not increase risk of human harm. Combined, the level of inaccuracy makes these results non-actionable as bias exists due to the small sample size and measurement error.
